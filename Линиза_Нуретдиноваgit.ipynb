# %% [markdown]
# <a href="https://colab.research.google.com/github/Lili786965/python/blob/main/%D0%9B%D0%B8%D0%BD%D0%B8%D0%B7%D0%B0_%D0%9D%D1%83%D1%80%D0%B5%D1%82%D0%B4%D0%B8%D0%BD%D0%BE%D0%B2%D0%B0git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Инициализация нового локального репозитория - git init

# %% [markdown]
# ![Снимок экрана 2025-04-24 214459.png](data:image/png;base64,...)

# %% [markdown]
# 2) Добавление файлов в индекс для коммита - git add <file>

# %% [markdown]
# ![Снимок экрана 2025-04-24 214754.png](data:image/png;base64,...)

# %% [markdown]
# 3) Создание нового коммита - git commit -m "Commit message"

# %% [markdown]
# ![Снимок экрана 2025-04-24 214959.png](data:image/png;base64,...)

# %% [markdown]
# 4) Просмотр истории коммитов - git log

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4) Просмотр истории коммитов - git log

# %% [markdown]
# ![Снимок экрана 2025-04-24 215740.png](data:image/png;base64,...)

# %% [markdown]
# 5) Просмотр изменений в файлах перед коммитом - git diff

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6) Откат изменений в файле до предыдущего коммита - git checkout -- <file>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 7) Создание новой ветки - git branch <branch_name>
# 8) Переключение между ветками - git checkout <branch_name>
# 9) Слияние веток - git merge <branch_name>
# 10) Удаление ветки - git branch -d <branch_name>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 11) Изменение сообщения последнего коммита - git commit --amend

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 12) Удаление файла из репозитория и истории коммитов - git rm <file>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 13) Игнорирование файлов и папок с помощью .gitignore - создание и
# редактирование файла .gitignore

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 14) Просмотр различий между ветками - git diff <branch1> <branch2>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 15) Отмена изменений в файле после добавления в индекс - git reset HEAD
# <file>
# 16) Просмотр информации о состоянии репозитория - git status

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 17) Переименование файлов - git mv <old_file> <new_file>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 18) Отображение информации о коммите - git show <commit_id>
# 19) Возврат к определенному коммиту - git checkout <commit_id>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 20) Создание и применение патчей - git format-patch и git apply

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 21) Изменение порядка коммитов - git rebase -i

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 22) Изменение авторства коммитов - git commit --amend --author="Author
# Name <email>"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 23) Изменение истории коммитов с помощью rebase - git rebase

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 24) Использование stash для временного сохранения изменений - git stash и
# git stash apply

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 25) Применение изменений из одной ветки в другую с помощью cherry-pick
# - git cherry-pick <commit_id>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 26) Просмотр информации о ветках и удаленных репозиториях - git branch,
# git remote -v

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 27) Изменение URL удаленного репозитория - git remote set-url origin
# <new_url>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 28) Удаление коммитов из истории - git reset или git rebase -i

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 29) Использование алиасов для команд Git - git config --global
# alias.<alias_name> "<command>"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 30) Использование подмодулей для работы с вложенными репозиториями -
# git submodule

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1) Клонировать удаленный репозиторий на локальную машину. (git clone)
# 2) Добавить новый удаленный репозиторий в существующий проект. (git
# remote add)
# 3) Посмотреть список удаленных репозиториев, связанных с локальным
# проектом. (git remote -v)
# 4) Посмотреть информацию о удаленном репозитории (например, URL). (git
# remote show)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5) Изменить URL удаленного репозитория. (git remote set-url)
# 6) Добавить новый файл в удаленный репозиторий. (git add, git commit, git
# push)7) Закоммитить изменения и отправить их в удаленный репозиторий. (git
# commit, git push)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 8) Посмотреть различия между локальным и удаленным репозиториями. (git
# diff, git difftool)
# 9) Получить изменения из удаленного репозитория на локальную машину.
# (git fetch, git pull)
# 10) Отправить ветку в удаленный репозиторий. (git push)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 12) Переименовать удаленную ветку. (git branch -m, git push origin
# :old_branch_name new_branch_name)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 13) Переместить удаленную ветку. (git push origin :branch_name
# destination_branch_name)

# %% [markdown]
# ![image.png](
# )

# %% [markdown]
# 14) Создать тег и отправить его в удаленный репозиторий. (git tag, git push -
# -tags)
# 15) Удалить тег из удаленного репозитория. (git push origin --delete tag_name)
# 16) Просмотреть историю коммитов на удаленном репозитории. (git log, gitk,
# gitg)

# %% [markdown]
# ![Снимок экрана 2025-04-25 142252.png](data:image/png;base64,...)

# %% [markdown]
# 17) Отменить последний коммит и отправить изменения в удаленный
# репозиторий. (git reset, git push -f)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 18) Просмотреть информацию о ветках на удаленном репозитории. (git
# branch -r)

# %% [markdown]
# ![image.png](
# ![Снимок экрана 2025-04-25 143258.png](data:image/png;base64,...))

# %% [markdown]
# 19) Изменить настройки удаленного репозитория (например, upstream). (git
# remote set-url)
# 20) Поделиться ссылкой на удаленный репозиторий с коллегами. (ссылка на
# репозиторий)
# 21) Посмотреть список веток на удаленном репозитории. (git branch -r)
# 22) Изменить права доступа к удаленному репозиторию. (настройки
# удаленного сервера)
# 23) Просмотреть список вкладчиков в удаленном репозитории. (настройки
# удаленного сервера)

# %% [markdown]
# > Add blockquote
#
# > Add blockquote![Снимок экрана 2025-04-25 144043.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 26) Удалить файл из удаленного репозитория. (git rm, git commit, git push)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 27) Восстановить удаленный файл из истории удаленного репозитория. (git
# checkout)

# %% [markdown]
# 27) Восстановить удаленный файл из истории удаленного репозитория. (git
# checkout)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 29) Просмотреть список тегов на удаленном репозитории. (git tag, git show)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 30) Сравнить различия между разными версиями удаленного репозитория.
# (git diff, git difftool)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 34) Отобразить информацию о удаленном репозитории. (git remote show)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 42) Изменить настройки отслеживания ветки на удаленном репозитории. (git
# branch --set-upstream-to)
# 43) Просмотреть информацию о вкладчиках в удаленном репозитории.
# (настройки удаленного сервера)
# 44) Просмотреть список удаленных веток. (git branch -r)47) Сравнить локальную ветку с удаленной версией. (git diff <local_branch>
# origin/<remote_branch>)
# 48) Изменить сообщение коммита, который еще не был отправлен в
# удаленный репозиторий. (git commit --amend)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 49) Восстановить удаленную ветку из удаленного репозитория. (git fetch, git
# checkout -b <branch> origin/<branch>)
# 50) Отобразить информацию о ветках на удаленном репозитории. (git lsremote, git remote show)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Словари, множества, кортежи

# %% [markdown]
# 1. Подсчет частоты слов: Напишите функцию, которая принимает строку и возвращает словарь, где ключи — это слова, а значения — их частота в строке.

# %%
from collections import defaultdict
import re

def dictCount(text):
    words = re.findall(r'\w+', text.lower())
    frequency = defaultdict(int)
    for words in words:
        frequency[words] += 1
    return dict(frequency)

text = input()
print(dictCount(text))
# Out:
# hello Hello 4 5 4 6 Liniza liniza
# {'hello': 2, '4': 2, '5': 1, '6': 1, 'liniza': 2}

# %% [markdown]
# 2. Инвертирование словаря: Напишите функцию, которая принимает словарь и возвращает новый словарь, где ключи и значения поменяны местами. Если значения не уникальны, объедините ключи в список.

# %%
def inverted_dict(original):
  inverted = {}
  for key, value in original.items():
    if value not in inverted:
      inverted[value] = key
    else:
      if not isinstance(inverted[value], list):
        inverted[value] = [inverted[value]]
      inverted[value].append(key)
  return inverted

dict1 = {1: "me", 2: "you", 3: "us"}
print(inverted_dict(dict1))
# Out:
# {'me': 1, 'you': 2, 'us': 3}

# %% [markdown]
# # 3. Слияние словарей: Напишите функцию, которая принимает два словаря и возвращает новый словарь, содержащий все ключи из обоих словарей. Если ключи совпадают, значения должны быть суммированы.

# %%
def merge_dicts(dict1, dict2):
    merged = dict1.copy()
    for key, value in dict2.items():
        if key in merged:
            merged[key] += value
        else:
            merged[key] = value
    return merged

# Пример использования
dict1 = {'a': 1, 'b': 2, 'c': 3}
dict2 = {'b': 3, 'c': 4, 'd': 5}

result = merge_dicts(dict1, dict2)
print(result)
# Out:
# {'a': 1, 'b': 5, 'c': 7, 'd': 5}

# %% [markdown]
# 4. Фильтрация по значению: Напишите функцию, которая принимает словарь и пороговое значение, и возвращает новый словарь, содержащий только те пары ключ-значение, где значение больше порогового.

# %%
def filter_dict(input_dict, threshold):
    return {key: value for key, value in input_dict.items() if value > threshold}

my_dict = {'a': 10, 'b': 5, 'c': 15, 'd': 3, 'e': 20}
value1 = 7

filtered_dict = filter_dict(my_dict, value1)
print(filtered_dict)
# Out:
# {'a': 10, 'c': 15, 'e': 20}

# %% [markdown]
# 5. Максимальное значение: Напишите функцию, которая находит ключ с максимальным значением в словаре.

# %%
def find_max_key(dictionary):
    if not dictionary:
        return None
    return max(dictionary, key=dictionary.get)
my_dict = {'a': 10, 'b': 25, 'c': 15, 'd': 30, 'e': 5}
max_key = find_max_key(my_dict)
print(max_key)

# %% [markdown]
# 6. Удаление ключей: Напишите функцию, которая принимает словарь и список ключей, и удаляет из словаря все указанные ключи.

# %%
def remove_keys(dictionary, keys_to_remove):
    for key in keys_to_remove:
        dictionary.pop(key, None)
    return dictionary
my_dict = {'a': 1, 'b': 2, 'c': 3, 'd': 4}
keys = ['b', 'd', 'x']
result = remove_keys(my_dict, keys)
print(result)

# %% [markdown]
# 7. Группировка по длине ключей: Напишите функцию, которая группирует ключи словаря по их длине и возвращает словарь, где ключи — это длины, а значения — списки ключей соответствующей длины.

# %%
def group_keys_by_length(dictionary):
    result = {}
    for key in dictionary.keys():
        length = len(str(key))
        if length not in result:
            result[length] = []
        result[length].append(key)
    return result

my_dict = {
    'Liniza': 1,
    'Tasya': 2,
    'Zlata': 3,
    42: 4,
    'orange': 5,
    'pear': 6,
    (1, 2): 7
}

grouped = group_keys_by_length(my_dict)
print(grouped)
# Out:
# {6: ['Liniza', 'orange', (1, 2)], 5: ['Tasya', 'Zlata'], 2: [42], 4: ['pear']}

# %% [markdown]
# 8. Сумма значений: Напишите функцию, которая вычисляет сумму всех значений в словаре.

# %%
def sum_dict_values(dictionary):
    return sum(dictionary.values())

my_dict = {'a': 8, 'b': 56, 'c': 82}
total = sum_dict_values(my_dict)
print(total)
# Out:
# 146

# %% [markdown]
# 9. Обновление значений: Напишите функцию, которая увеличивает все значения в словаре на заданное число.

# %%
def increase_values(dictionary, increment):
    return {key: value + increment for key, value in dictionary.items()}

my_dict = {'a': 7, 'b': 82, 'c': 35}
updated_dict = increase_values(my_dict, 5)
print(updated_dict)
# Out:
# {'a': 12, 'b': 87, 'c': 40}

# %% [markdown]
# 10. Глубокая копия словаря: Напишите функцию, которая создает глубокую копию словаря, включая все вложенные структуры данных.

# %%
import copy

def deep_copy_dict(original_dict):
    return copy.deepcopy(original_dict)

original = {
    'birds': 1,
    'crow': [2, 3, 4],
    'owl': {'bird': 10, 'animal': 20},
    'pigeon': {'nested': {'deep': [5, 6]}}
}

copied = deep_copy_dict(original)
copied['crow'].append(5)
copied['owl']['bird'] = 100
copied['pigeon']['nested']['deep'].append(7)

print("Оригинал:", original)
print("Копия:", copied)
# Out:
# Оригинал: {'birds': 1, 'crow': [2, 3, 4], 'owl': {'bird': 10, 'animal': 20}, 'pigeon': {'nested': {'deep': [5, 6]}}}
# Копия: {'birds': 1, 'crow': [2, 3, 4, 5], 'owl': {'bird': 100, 'animal': 20}, 'pigeon': {'nested': {'deep': [5, 6, 7]}}}

# %% [markdown]
# 1. Создание множества из списка: Напишите функцию, которая принимает список и возвращает множество, содержащее уникальные элементы списка.

# %%
def list_to_set(input_list):
    return set(input_list)

my_list = [1, 2, 2, 3, 4, 4, 4, 5]
unique_set = list_to_set(my_list)
print(unique_set)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 2. Симметрическая разность: Напишите функцию, которая принимает два множества и возвращает их симметрическую разность.

# %%
def symmetric_difference(set1, set2):
    return set1 ^ set2

a = {1, 2, 3, 4}
b = {3, 4, 5, 6}
result = symmetric_difference(a, b)
print(result)
# Out:
# {1, 2, 5, 6}

# %% [markdown]
# 3. Максимальный элемент: Напишите функцию, которая находит максимальный элемент в множестве.

# %%
def max_in_set(input_set):
    if not input_set:
        raise ValueError("Множество пустое")
    return max(input_set)

numbers = {45, 23, 82, 67, 56, 0}
print(max_in_set(numbers))
strings = {"apple", "banana", "pear"}
print(max_in_set(strings))

# %% [markdown]
# 4. Объединение нескольких множеств: Напишите функцию, которая принимает список множеств и возвращает их объединение.

# %%
def union_of_sets(list_of_sets):
    result = set()
    for s in list_of_sets:
        result.update(s)
    return result
sets = [{1, 2, 3}, {3, 4, 5}, {5, 6, 7}]
print(union_of_sets(sets))
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %% [markdown]
# 5. Пересечение нескольких множеств: Напишите функцию, которая принимает список множеств и возвращает их пересечение.

# %%
def intersection(list_of_sets):
    if not list_of_sets:
        return set()
    result = list_of_sets[0].copy()
    for s in list_of_sets[1:]:
        result.intersection_update(s)
    return result

sets = [{1, 2, 3}, {2, 3, 4}, {3, 4, 5}]
print(intersection(sets))

# %% [markdown]
# 6. Разбиение множества: Напишите функцию, которая разбивает множество на два: одно с четными числами, другое с нечетными.

# %%
def split_set(input_set):
    even = {x for x in input_set if x % 2 == 0}
    odd = {x for x in input_set if x % 2 != 0}
    return even, odd

numbers = {1, 2, 3, 4, 5, 6}
even, odd = split_set(numbers)
print(even)
print(odd)
# Out:
# {2, 4, 6}
# {1, 3, 5}

# %% [markdown]
# 7. Фильтрация по условию: Напишите функцию, которая фильтрует множество, оставляя только те элементы, которые удовлетворяют заданному условию (например, больше 10).

# %%
def filter_set(input_set, condition):
    return {x for x in input_set if condition(x)}

numbers = {5, 10, 15, 20, 25}
filtered = filter_set(numbers, lambda x: x > 10)
print(filtered)
# Out:
# {25, 20, 15}

# %% [markdown]
# 8. Генерация множества: Напишите функцию, которая генерирует множество из n случайных чисел в заданном диапазоне.

# %%
import random

def generate_random_set(n, start, end):
    return {random.randint(start, end) for _ in range(n)}

random_set = generate_random_set(5, 1, 10)
print(random_set)
# Out:
# {2, 5, 8, 9, 10}

# %% [markdown]
# 9. Объединение с сохранением порядка: Напишите функцию, которая объединяет два множества и возвращает результат в виде отсортированного списка. напиши код на питоне для этих заданий и чтобы в коде не было комментариев

# %%
def union_sorted(set1, set2):
    return sorted(set1.union(set2))

a = {5, 1, 3}
b = {4, 2, 6}
print(union_sorted(a, b))

# %% [markdown]
# 10. Удаление случайного элемента: Напишите функцию, которая удаляет случайный элемент из множества.

# %%
import random

def remove_random_element(input_set):
    if not input_set:
        return set()
    element = random.choice(list(input_set))
    input_set.remove(element)
    return input_set

numbers = {10, 20, 30, 40, 50}
print(remove_random_element(numbers))

# %% [markdown]
# 1. Создание кортежа из списка: Напишите функцию, которая принимает список и возвращает кортеж, содержащий те же элементы.

# %%
def list_to_tuple(input_list):
    return tuple(input_list)

my_list = [1, 2, 3, 4, 5]
result = list_to_tuple(my_list)
print(result)
print(type(result))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %% [markdown]
# 2. Вложенные кортежи: Напишите функцию, которая создает вложенный кортеж, где первый уровень — это буквы алфавита, а второй уровень — числа от 1 до 5.

# %%
def nested_tuple():
    letters = tuple('abcdefghijklmnopqrstuvwxyz')
    numbers = tuple(range(1, 6))
    return tuple((letter, numbers) for letter in letters[:5])

print(nested_tuple())
# Out:
# (('a', (1, 2, 3, 4, 5)), ('b', (1, 2, 3, 4, 5)), ('c', (1, 2, 3, 4, 5)), ('d', (1, 2, 3, 4, 5)), ('e', (1, 2, 3, 4, 5)))

# %% [markdown]
# 2.Развертывание вложенного кортежа: Напишите функцию, которая разворачивает вложенный кортеж в плоский кортеж.

# %%
def flatten_tuple(nested):
    return tuple(item for sublist in nested for item in (sublist if isinstance(sublist, tuple) else (sublist,)))

nested = ((1, (2, 3)), (4, (5, 6)))
print(flatten_tuple(nested))
# Out:
# (1, (2, 3), 4, (5, 6))

# %% [markdown]
# 3. Кортеж из двух списков: Напишите функцию, которая создает кортеж пар из двух списков одинаковой длины.

# %%
def paired_tuple(list1, list2):
    return tuple(zip(list1, list2))

list1 = [1, 2, 3]
list2 = ['a', 'b', 'c']
print(paired_tuple(list1, list2))
# Out:
# ((1, 'a'), (2, 'b'), (3, 'c'))

# %% [markdown]
# 4. Перевод кортежа в строку: Напишите функцию, которая преобразует кортеж строк в одну строку, объединяя их через пробел.

# %%
def tuple_to_string(tup):
    return ' '.join(tup)

tup = ('Hello', 'world', '!')
print(tuple_to_string(tup))
# Out:
# Hello world !

# %% [markdown]
# 5. Перевод строки в кортеж чисел: Напишите функцию, которая преобразует строку чисел, разделенных запятыми, в кортеж чисел.

# %%
def string_to_tuple(s):
    return tuple(map(int, s.split(',')))

s = "1,2,3,4,5"
print(string_to_tuple(s))
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# 6. Кортеж с четными числами: Напишите функцию, которая создает кортеж, содержащий только четные числа из заданного диапазона.

# %%
def even_numbers(start, end):
    return tuple(i for i in range(start, end + 1) if i % 2 == 0)

print(even_numbers(1, 10))
# Out:
# (2, 4, 6, 8, 10)

# %% [markdown]
# 7. Кортеж с палиндромами: Напишите функцию, которая создает кортеж, содержащий только строки-палиндромы из заданного списка строк. напиши код отдельно для каждого задания и чтобы в коде не было коментариев

# %%
def is_palindrome(s):
    return s == s[::-1]

def palindrome_tuple(strings):
    return tuple(s for s in strings if is_palindrome(s))

strings = ('madam', 'hello', 'level', 'world')
print(palindrome_tuple(strings))
# Out:
# ('madam', 'level')

# %% [markdown]
# 8. Группировка элементов: Напишите функцию, которая группирует элементы кортежа по их типам (например, int, str, float) и возвращает словарь, где ключи — это типы, а значения — списки элементов.

# %%
def group_by_type(input_tuple):
    result = {}
    for item in input_tuple:
        item_type = type(item).__name__
        if item_type not in result:
            result[item_type] = []
        result[item_type].append(item)
    return result

my_tuple = (1, 2.5, 'hello', 3, 'world', 4.2, True)
print(group_by_type(my_tuple))
# Out:
# {'int': [1, 3], 'float': [2.5, 4.2], 'str': ['hello', 'world'], 'bool': [True]}

# %% [markdown]
# 9. Проверка на наличие элемента: Напишите функцию, которая проверяет, содержится ли заданный элемент в кортеже.

# %%
def is_in_tuple(t, element):
    return element in t

my_tuple = (1, 2, 3, 'a', 'b', 'c')
print(is_in_tuple(my_tuple, 2))
print(is_in_tuple(my_tuple, 'x'))
# Out:
# True
# False

# %% [markdown]
# 10. Количество вхождений элемента: Напишите функцию, которая подсчитывает, сколько раз заданный элемент встречается в кортеже.

# %%
def is_in_tuple(t, element):
    return element in t

my_tuple = (1, 2, 3, 'a', 'b', 'c')
print(is_in_tuple(my_tuple, 2))
print(is_in_tuple(my_tuple, 'x'))
